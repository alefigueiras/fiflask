# %%
import requests
import pandas
from bokeh.plotting import figure

# %%
url = 'http://api.worldbank.org/countries/all/indicators/SP.POP.TOTL?format=json&date=2000:2001'
response = requests.get(url)
json = response.json()

# %%
json
# Out:
# [{u'page': 1, u'pages': 10, u'per_page': u'50', u'total': 496},
#  [{u'country': {u'id': u'1A', u'value': u'Arab World'},
#    u'date': u'2001',
#    u'decimal': u'0',
#    u'indicator': {u'id': u'SP.POP.TOTL', u'value': u'Population, total'},
#    u'value': u'287358599'},
#   {u'country': {u'id': u'1A', u'value': u'Arab World'},
#    u'date': u'2000',
#    u'decimal': u'0',
#    u'indicator': {u'id': u'SP.POP.TOTL', u'value': u'Population, total'},
#    u'value': u'281355774'},
#   {u'country': {u'id': u'S3', u'value': u'Caribbean small states'},
#    u'date': u'2001',
#    u'decimal': u'0',
#    u'indicator': {u'id': u'SP.POP.TOTL', u'value': u'Population, total'},
#    u'value': u'6497461'},
#   {u'country': {u'id': u'S3', u'value': u'Caribbean small states'},
#    u'date': u'2000',
#    u'decimal': u'0',
#    u'indicator': {u'id': u'SP.POP.TOTL', u'value': u'Population, total'},
#    u'value': u'6454716'},
# ...

# %%
country = json[1][0]['country']['value']

# %%
country
# Out:
# u'Arab World'

# %%
indicatorname = json[1][0]['indicator']['value']

# %%
indicatorname
# Out:
# u'Population, total'

# %%
indicatorvalue = json[1][0]['value']

# %%
indicatorvalue
# Out:
# u'287358599'

# %%
#hasta aquí avance

# %%
df = pandas.DataFrame(data)

# %%
df
# Out:
#             0
# 0          1A
# 1  Arab World

# %%
url = 'https://www.quandl.com/api/v3/datasets/WIKI/%s.json?api_key=XQKAhbrdid5hNyDptPBx&start_date=%s'
response = requests.get(url % ('goog', '2014-01-01'))
json = response.json()

# %%
json
# Out:
# {u'dataset': {u'collapse': None,
#   u'column_index': None,
#   u'column_names': [u'Date',
#    u'Open',
#    u'High',
#    u'Low',
#    u'Close',
#    u'Volume',
#    u'Ex-Dividend',
#    u'Split Ratio',
#    u'Adj. Open',
#    u'Adj. High',
#    u'Adj. Low',
#    u'Adj. Close',
#    u'Adj. Volume'],
#   u'data': [[u'2016-06-16',
#     714.91,
#     716.65,
#     703.26,
#     710.36,
#     1970781.0,
#     0.0,
#     1.0,
#     714.91,
#     716.65,
#     703.26,
#     710.36,
#     1970781.0],
#    [u'2016-06-15',
#     719.0,
#     722.98,
#     717.31,
#     718.92,
#     1202739.0,
#     0.0,
#     1.0,
#     719.0,
#     722.98,
#     717.31,
#     718.92,
#     1202739.0],
#    [u'2016-06-14',
#     716.48,
#     722.47,
#     713.12,
#     718.27,
#     1300844.0,
#     0.0,
#     1.0,
#     716.48,
#     722.47,
#     713.12,
#     718.27,
#     1300844.0],
#    [u'2016-06-13',
#     716.51,
#     725.44,
#     716.51,
#     718.36,
#     1221746.0,
#     0.0,
#     1.0,
# ...
